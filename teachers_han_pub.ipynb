# %% [markdown]
# # Analysis teacher survey results (HAN only)
#
# Combined results for clusters and categories

# %%
# Imports
import os
import sys
sys.path.append(os.path.dirname(os.path.abspath('')))
# print(sys.path)
import pandas as pd
import datetime
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# import seaborn as sns
import matplotlib.ticker as ticker
import math
import pingouin as pg

# %%
# Load base ABT
abt = pd.read_excel('../data/survey results/teachers all values only.xlsx')
# abt = pd.read_excel('../data/survey results/teachers han values only.xlsx')
abt
# Out:
#     Cluster: complexity  Cluster: side effects  Cluster: reusability  \
# 0                   4.0                      3                     2
# 1                   3.0                      3                     2
# 2                   4.0                      2                     5
# 3                   2.0                      5                     3
# 4                   3.0                      3                     3
# 5                   2.0                      2                     3
# 6                   3.0                      2                     4
# 7                   3.0                      2                     2
# 8                   2.0                      5                     3
# 9                   4.0                      4                     5
# 10                  NaN                      4                     5
# 11                  3.0                      1                     4
# 12                  3.0                      4                     3
# 13                  5.0                      1                     5
# 14                  NaN                      1                     3
# 15                  3.0                      4                     5
# 16                  3.0                      3                     4
# 17                  3.0                      3                     4
# 18                  4.0                      3                     4
# 19                  5.0                      4                     3
# 20                  4.0                      4                     4
# 21                  3.0                      5                     4
# 22                  4.0                      5                     5
# 23                  4.0                      5                     4
#
#     Cluster: incomplete  Cluster: best practices  Category: CodeStyle  \
# 0                     1                        2                    3
# 1                     4                        4                    3
# 2                     5                        2                    1
# 3                     3                        5                    3
# 4                     3                        5                    5
# 5                     3                        4                    4
# 6                     3                        4                    4
# 7                     3                        2                    2
# 8                     1                        4                    3
# 9                     5                        4                    4
# 10                    3                        3                    2
# 11                    4                        3                    3
# 12                    3                        2                    4
# 13                    5                        2                    4
# 14                    3                        4                    3
# 15                    3                        4                    3
# 16                    3                        3                    4
# 17                    3                        3                    3
# 18                    3                        4                    4
# 19                    5                        2                    5
# 20                    4                        4                    3
# 21                    3                        4                    3
# 22                    5                        4                    5
# 23                    5                        4                    3
#
#     Category: ErrorProne  Category: SizeViolations  Category: Design
# 0                    4.0                         2                 4
# 1                    2.0                         1                 3
# 2                    4.0                         3                 2
# 3                    3.0                         2                 3
# 4                    3.0                         4                 3
# 5                    NaN                         4                 4
# 6                    3.0                         3                 2
# 7                    1.0                         1                 2
# 8                    1.0                         2                 5
# 9                    4.0                         4                 4
# 10                   1.0                         4                 3
# 11                   2.0                         3                 4
# 12                   4.0                         3                 3
# 13                   1.0                         4                 5
# 14                   3.0                         4                 3
# 15                   4.0                         2                 5
# 16                   4.0                         3                 5
# 17                   3.0                         4                 4
# 18                   3.0                         4                 4
# 19                   3.0                         3                 4
# 20                   5.0                         4                 3
# 21                   3.0                         4                 5
# 22                   5.0                         4                 4
# 23                   2.0                         3                 3

# %%
# Some NaNs (3 records out of 23 total with 1 NaN each). Fill them with the median
for col in abt.columns:
    abt[col] = abt[col].fillna(abt[col].median())
abt
# Out:
#     Cluster: complexity  Cluster: side effects  Cluster: reusability  \
# 0                   4.0                      3                     2
# 1                   3.0                      3                     2
# 2                   4.0                      2                     5
# 3                   2.0                      5                     3
# 4                   3.0                      3                     3
# 5                   2.0                      2                     3
# 6                   3.0                      2                     4
# 7                   3.0                      2                     2
# 8                   2.0                      5                     3
# 9                   4.0                      4                     5
# 10                  3.0                      4                     5
# 11                  3.0                      1                     4
# 12                  3.0                      4                     3
# 13                  5.0                      1                     5
# 14                  3.0                      1                     3
# 15                  3.0                      4                     5
# 16                  3.0                      3                     4
# 17                  3.0                      3                     4
# 18                  4.0                      3                     4
# 19                  5.0                      4                     3
# 20                  4.0                      4                     4
# 21                  3.0                      5                     4
# 22                  4.0                      5                     5
# 23                  4.0                      5                     4
#
#     Cluster: incomplete  Cluster: best practices  Category: CodeStyle  \
# 0                     1                        2                    3
# 1                     4                        4                    3
# 2                     5                        2                    1
# 3                     3                        5                    3
# 4                     3                        5                    5
# 5                     3                        4                    4
# 6                     3                        4                    4
# 7                     3                        2                    2
# 8                     1                        4                    3
# 9                     5                        4                    4
# 10                    3                        3                    2
# 11                    4                        3                    3
# 12                    3                        2                    4
# 13                    5                        2                    4
# 14                    3                        4                    3
# 15                    3                        4                    3
# 16                    3                        3                    4
# 17                    3                        3                    3
# 18                    3                        4                    4
# 19                    5                        2                    5
# 20                    4                        4                    3
# 21                    3                        4                    3
# 22                    5                        4                    5
# 23                    5                        4                    3
#
#     Category: ErrorProne  Category: SizeViolations  Category: Design
# 0                    4.0                         2                 4
# 1                    2.0                         1                 3
# 2                    4.0                         3                 2
# 3                    3.0                         2                 3
# 4                    3.0                         4                 3
# 5                    3.0                         4                 4
# 6                    3.0                         3                 2
# 7                    1.0                         1                 2
# 8                    1.0                         2                 5
# 9                    4.0                         4                 4
# 10                   1.0                         4                 3
# 11                   2.0                         3                 4
# 12                   4.0                         3                 3
# 13                   1.0                         4                 5
# 14                   3.0                         4                 3
# 15                   4.0                         2                 5
# 16                   4.0                         3                 5
# 17                   3.0                         4                 4
# 18                   3.0                         4                 4
# 19                   3.0                         3                 4
# 20                   5.0                         4                 3
# 21                   3.0                         4                 5
# 22                   5.0                         4                 4
# 23                   2.0                         3                 3

# %% [markdown]
# ## Responses

# %%
ncols = 2
nrows = math.ceil(len(abt.columns) / ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize = (10, 20))
col = 0
row = 0
for col_name in abt.columns:
    # print(f'Name {col_name} Row {row} col {col}')
    ax = abt[col_name].hist(
        ax = axes[row, col],
        bins = [1, 2, 3, 4, 5, 6], 
        rwidth = 0.7, 
        range = [ 1, 2, 3, 4, 5, 6],
        align = "left")
    ax.grid(False)
    ax.set_xlabel('Importance (1 - 5)')
    ax.set_ylabel('Count')
    ax.set_title(col_name)
    
    ax.set_xticks([1, 2, 3, 4, 5])
    col = col + 1
    if col >= ncols:
        col = 0
        row = row + 1


# Only works because I know it's only the last one that doesn't exist.
axes[-1, -1].axis('off')

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Median values and percentiles
#
# The spread is fairly large, so these values are likely not very significant.

# %%
summary = {}
num_recs = len(abt)



for col in abt.columns:
    col_summary = {
        'median' : abt[col].median().astype('int')
    }
    
    for val in range(1, 6):
        col_summary[f'Perc. {val}'] = int((len(abt[abt[col] == val]) / num_recs) * 100)

    # 1 and 2 : unimportant.
    # 2, 3 and 4: average
    # 4 and 5: important
    col_summary["Perc. unimportant (1, 2)"] = int((len(abt[abt[col] < 3]) / num_recs) * 100) 
    col_summary["Perc. average (2, 3, 4)"] = int((len(abt[abt[col].between(1, 5, inclusive='neither')]) / num_recs) * 100) 
    col_summary["Perc. important (4, 5)"] = int((len(abt[abt[col] > 3]) / num_recs) * 100)    

    # Weighted average

    weights_sum = abt[abt[col] == 1][col].sum() + \
                                        abt[abt[col] == 2][col].apply(lambda x : 2).sum() + \
                                        abt[abt[col] == 3][col].apply(lambda x : 3).sum() + \
                                        abt[abt[col] == 4][col].apply(lambda x : 4).sum() + \
                                        abt[abt[col] == 5][col].apply(lambda x : 5).sum()
    weights_val = abt[abt[col] == 1][col].sum() + \
                                        abt[abt[col] == 2][col].sum() * 2 + \
                                        abt[abt[col] == 3][col].sum() * 3 + \
                                        abt[abt[col] == 4][col].sum() * 4 + \
                                        abt[abt[col] == 5][col].sum() * 5
    col_summary["Weighted average"] = float(round((weights_val / weights_sum) * 10)) / 10
    # col_summary["Weighted average"] = weights_sum
    summary[col] = col_summary

df_summary = pd.DataFrame.from_dict(summary)
df_summary.to_clipboard()
df_summary
# Out:
#                           Cluster: complexity  Cluster: side effects  \
# median                                    3.0                    3.0
# Perc. 1                                   0.0                   12.0
# Perc. 2                                  12.0                   16.0
# Perc. 3                                  50.0                   25.0
# Perc. 4                                  29.0                   25.0
# Perc. 5                                   8.0                   20.0
# Perc. unimportant (1, 2)                 12.0                   29.0
# Perc. average (2, 3, 4)                  91.0                   66.0
# Perc. important (4, 5)                   37.0                   45.0
# Weighted average                          3.5                    3.8
#
#                           Cluster: reusability  Cluster: incomplete  \
# median                                     4.0                  3.0
# Perc. 1                                    0.0                  8.0
# Perc. 2                                   12.0                  0.0
# Perc. 3                                   29.0                 54.0
# Perc. 4                                   33.0                 12.0
# Perc. 5                                   25.0                 25.0
# Perc. unimportant (1, 2)                  12.0                  8.0
# Perc. average (2, 3, 4)                   75.0                 66.0
# Perc. important (4, 5)                    58.0                 37.0
# Weighted average                           4.0                  3.8
#
#                           Cluster: best practices  Category: CodeStyle  \
# median                                        4.0                  3.0
# Perc. 1                                       0.0                  4.0
# Perc. 2                                      25.0                  8.0
# Perc. 3                                      16.0                 45.0
# Perc. 4                                      50.0                 29.0
# Perc. 5                                       8.0                 12.0
# Perc. unimportant (1, 2)                     25.0                 12.0
# Perc. average (2, 3, 4)                      91.0                 83.0
# Perc. important (4, 5)                       58.0                 41.0
# Weighted average                              3.7                  3.6
#
#                           Category: ErrorProne  Category: SizeViolations  \
# median                                     3.0                       3.0
# Perc. 1                                   16.0                       8.0
# Perc. 2                                   12.0                      16.0
# Perc. 3                                   37.0                      29.0
# Perc. 4                                   25.0                      45.0
# Perc. 5                                    8.0                       0.0
# Perc. unimportant (1, 2)                  29.0                      25.0
# Perc. average (2, 3, 4)                   75.0                      91.0
# Perc. important (4, 5)                    33.0                      45.0
# Weighted average                           3.4                       3.4
#
#                           Category: Design
# median                                 4.0
# Perc. 1                                0.0
# Perc. 2                               12.0
# Perc. 3                               33.0
# Perc. 4                               33.0
# Perc. 5                               20.0
# Perc. unimportant (1, 2)              12.0
# Perc. average (2, 3, 4)               79.0
# Perc. important (4, 5)                54.0
# Weighted average                       3.9

# %% [markdown]
# # Cronbach's Alpha
#
# Determine the internal consistency of the results. Use the interpretation of Cronbach's alpha defined by George and Mallery (2003) as quoted in Gliem and Gliem (2003):
#
# - _ > .9 – Excellent
# - _ > .8 – Good
# - _ > .7 – Acceptable
# - _ > .6 – Questionable
# - _ > .5 – Poor
# - _ < .5 – Unacceptable

# %%
pg.cronbach_alpha(data=abt)
# Out:
# (0.6310406698564595, array([0.361, 0.817]))

# %%
individual = [
    {'title' : 'HAN SPAD',
     'path' : '../data/survey results/han spad values only.xlsx'},
    {'title' : 'HAN OOPD',
     'path' : '../data/survey results/han oopd values only.xlsx'},
    {'title' : 'HU OOP',
     'path' : '../data/survey results/hu oop values only.xlsx'},
]

cronbach_output = ''
for assignment in individual:
    cronbach_output += f"<h2>{assignment['title']}</h2>"
    abt_assignment = pd.read_excel(assignment['path'])
    for col in abt_assignment.columns:
        abt_assignment[col] = abt_assignment[col].fillna(abt_assignment[col].median())
    cronbach_output += '<h3>Complete</h3>'
    cronbach_output += f"<p>{pg.cronbach_alpha(data = abt_assignment)}</p>"
    cronbach_output += '<h3>Clusters and categories only</h3>'
    abt_cc_only = abt_assignment[[x for x in abt_assignment.columns if not x.startswith('Criterium')]]
    cronbach_output += f"<p>{pg.cronbach_alpha(data = abt_cc_only)}</p>"


from IPython.core.display import HTML
HTML(cronbach_output)
# Out:
# <h2>HAN SPAD</h2><h3>Complete</h3><p>(0.6351278357940222, array([0.223, 0.883]))</p><h3>Clusters and categories only</h3><p>(0.5963114754098361, array([0.107, 0.873]))</p><h2>HAN OOPD</h2><h3>Complete</h3><p>(0.15792838874680312, array([-0.96 ,  0.775]))</p><h3>Clusters and categories only</h3><p>(0.3841463414634146, array([-0.476,  0.837]))</p><h2>HU OOP</h2><h3>Complete</h3><p>(-2.2941176470588234, array([-11.258,   0.767]))</p><h3>Clusters and categories only</h3><p>(-2.2941176470588234, array([-11.258,   0.767]))</p>
